# %%
from pathlib import Path
import os

WORK_DIR = Path.cwd().resolve()

os.environ["SCRIPT_DIR"] = str(WORK_DIR) + "/code"
os.environ["RESULTS_DIR"] = str(WORK_DIR) +  "/results"
os.environ["PYTHONUNBUFFERED"] = "1"
os.environ["PYTHONWARNINGS"] = "ignore"

os.makedirs(os.environ["RESULTS_DIR"], exist_ok=True)

print(f"SCRIPT_DIR = {os.environ['SCRIPT_DIR']}")
print(f"RESULTS_DIR = {os.environ['RESULTS_DIR']}")
# Out:
# SCRIPT_DIR = /workspace/code
# RESULTS_DIR = /workspace/results

# %%
# %%bash
# exec 2>&1
# echo "Running ViSNet-PIMA inference on MD22, Chignolin, Trp-cage, and NCIA datasets..."
# cd "${SCRIPT_DIR}/ViSNet-PIMA_test_on_Chig_and_MD22"
# bash inference_Chig.sh "$@"
# bash inference_MD22.sh "$@"
# Out:
# Running ViSNet-PIMA inference on MD22, Chignolin, Trp-cage, and NCIA datasets...
# Fri Sep 18 09:21:18 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.99.02              Driver Version: 595.99.02      CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5090        Off |   00000000:02:00.0 Off |                  N/A |
# | 56%   25C    P8             11W /  575W |       2MiB /  32607MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Seed set to 1
# train 79632, val 9954, test 9954
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Inferencing......
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2489/2489 0:02:02 • 0:00:00 20.27it/s it/s it/s
# Energy MAE: 1.9873 kcal/mol
# Forces MAE: 0.4798 kcal/mol/A
# Fri Sep 18 09:23:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.99.02              Driver Version: 595.99.02      CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5090        Off |   00000000:02:00.0 Off |                  N/A |
# | 66%   50C    P0             96W /  575W |       2MiB /  32607MiB |      2%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Seed set to 1
# train 5700, val 300, test 79109
# computing mean and std: 100%|██████████| 1425/1425 [00:06<00:00, 203.85it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Inferencing......
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19778/19778 0:14:48 • 0:00:00 22.81it/s it/s it/s
# Energy MAE: 0.0530 kcal/mol
# Forces MAE: 0.0744 kcal/mol/A
# Seed set to 1
# train 7600, val 400, test 61753
# computing mean and std: 100%|██████████| 950/950 [00:03<00:00, 251.43it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Inferencing......
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7720/7720 0:05:53 • 0:00:00 22.36it/s it/s it/s
# Energy MAE: 0.0784 kcal/mol
# Forces MAE: 0.0534 kcal/mol/A
# Seed set to 1
# train 7600, val 400, test 19272
# computing mean and std: 100%|██████████| 1900/1900 [00:07<00:00, 268.44it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Inferencing......
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4818/4818 0:03:31 • 0:00:00 22.16it/s it/s it/s
# Energy MAE: 0.0843 kcal/mol
# Forces MAE: 0.0677 kcal/mol/A
# Seed set to 1
# train 2850, val 150, test 17001
# computing mean and std: 100%|██████████| 357/357 [00:01<00:00, 216.91it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Inferencing......
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2126/2126 0:02:01 • 0:00:00 17.04it/s it/s it/s
# Energy MAE: 0.0772 kcal/mol
# Forces MAE: 0.0781 kcal/mol/A
# Seed set to 1
# train 1900, val 100, test 8153
# computing mean and std: 100%|██████████| 475/475 [00:01<00:00, 249.06it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Inferencing......
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2039/2039 0:01:45 • 0:00:00 19.37it/s it/s it/s
# Energy MAE: 0.1571 kcal/mol
# Forces MAE: 0.1142 kcal/mol/A
# Seed set to 1
# train 570, val 30, test 5502
# computing mean and std: 100%|██████████| 285/285 [00:01<00:00, 213.46it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Inferencing......
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2751/2751 0:02:05 • 0:00:00 22.03it/s it/s it/s
# Energy MAE: 0.2032 kcal/mol
# Forces MAE: 0.0935 kcal/mol/A
# Seed set to 1
# train 760, val 40, test 4232
# computing mean and std: 100%|██████████| 760/760 [00:02<00:00, 256.74it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Inferencing......
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4232/4232 0:05:00 • 0:00:00 14.49it/s it/s it/s
# Energy MAE: 0.4522 kcal/mol
# Forces MAE: 0.2243 kcal/mol/A

# %%
# %%bash
# exec 2>&1
# cd "${SCRIPT_DIR}/AI2BMD-PIMA_train"
# bash inference_Trp-cage.sh "$@"
# Out:
# Fri Sep 18 09:59:47 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.99.02              Driver Version: 595.99.02      CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5090        Off |   00000000:02:00.0 Off |                  N/A |
# | 85%   56C    P0            112W /  575W |       2MiB /  32607MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Starting learning curve and ablation study inference tasks, unit of "Scalar MAE" is eV, unit of "Forces MAE" is eV/Å
# Inference 20% Trp-cage finetuned model with pretraining...
# Seed set to 1
# train 0, val 0, test 101
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51/51 0:00:02 • 0:00:00 28.30it/s it/s it/s
# Scalar MAE: 0.149116
# Forces MAE: 0.029054
# Inference 40% Trp-cage finetuned model with pretraining...
# Seed set to 1
# train 0, val 0, test 101
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51/51 0:00:02 • 0:00:00 27.76it/s it/s it/s
# Scalar MAE: 0.121236
# Forces MAE: 0.025000
# Inference 60% Trp-cage finetuned model with pretraining...
# Seed set to 1
# train 0, val 0, test 101
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51/51 0:00:02 • 0:00:00 28.52it/s it/s it/s
# Scalar MAE: 0.110077
# Forces MAE: 0.022885
# Inference 80% Trp-cage finetuned model with pretraining...
# Seed set to 1
# train 0, val 0, test 101
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51/51 0:00:02 • 0:00:00 27.77it/s it/s it/s
# Scalar MAE: 0.103626
# Forces MAE: 0.021680
# Inference 100% Trp-cage finetuned model with pretraining...
# Seed set to 1
# train 0, val 0, test 101
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51/51 0:00:02 • 0:00:00 28.37it/s it/s it/s
# Scalar MAE: 0.094534
# Forces MAE: 0.020712
# Inference 100% Trp-cage finetuned model without pretraining...
# Seed set to 1
# train 0, val 0, test 101
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA GeForce RTX 5090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51/51 0:00:02 • 0:00:00 28.21it/s it/s it/s
# Scalar MAE: 0.145382
# Forces MAE: 0.025911
# All learning curve and ablation study inference tasks finished!

# %%
# %%bash
# exec 2>&1
# cd "${SCRIPT_DIR}/ViSNet-PIMA_test_on_NCIA"
# bash inference_NCIA.sh "$@"
# Out:
# Fri Sep 18 12:47:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.99.02              Driver Version: 595.99.02      CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5090        Off |   00000000:02:00.0 Off |                  N/A |
# | 55%   25C    P8             11W /  575W |       2MiB /  32607MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Loading model and parameters
# Processing NCIA_D1200.xyz
# MAE=1.780926, RMSE=4.276532 kcal/mol
# Processing NCIA_D442x10.xyz
# MAE=1.894466, RMSE=4.964783 kcal/mol
# Processing NCIA_HB300SPXx10.xyz
# MAE=1.792040, RMSE=3.042475 kcal/mol
# Processing NCIA_HB375x10.xyz
# MAE=0.282362, RMSE=0.447504 kcal/mol
# Processing NCIA_IHB100x10.xyz
# MAE=4.865469, RMSE=8.258852 kcal/mol
# Processing NCIA_R739x5.xyz
# MAE=0.963560, RMSE=1.815357 kcal/mol
# Processing NCIA_SH250x10.xyz
# MAE=6.733489, RMSE=18.368332 kcal/mol
# Overall: MAE=2.029629, RMSE=6.915084 kcal/mol
# Saved metrics to /workspace/results/log_NCIA/ncia_binding_visnet-pima.csv

# %%
# %%bash
# exec > >(tee "${RESULTS_DIR}/output.log") 2>&1
# python "${SCRIPT_DIR}/show_results.py"
# Out:
# ViSNet-PIMA reproduction results
# Results directory: /workspace/results
#
# MD22 in Table 1
# +------------------------+-------------------------+--------------------------+
# | Dataset                |  Energy MAE (kcal/mol)  |  Force MAE (kcal/mol/Å)  |
# +========================+=========================+==========================+
# | Ac-Ala3-NHMe           |         0.0530          |          0.0744          |
# | DHA                    |         0.0784          |          0.0534          |
# | Stachyose              |         0.0843          |          0.0677          |
# | AT-AT                  |         0.0772          |          0.0781          |
# | AT-AT-CG-CG            |         0.1571          |          0.1142          |
# | Buckyball catcher      |         0.2032          |          0.0935          |
# | Double-walled nanotube |         0.4522          |          0.2243          |
# +------------------------+-------------------------+--------------------------+
#
# AIMD-Chig in Fig. 2a and Fig. 2b
# +-----------+-------------------------+--------------------------+
# | Dataset   |  Energy MAE (kcal/mol)  |  Force MAE (kcal/mol/Å)  |
# +===========+=========================+==========================+
# | Chignolin |         1.9873          |          0.4798          |
# +-----------+-------------------------+--------------------------+
#
# Trp-cage learning curve and ablation study in Table S6 and Fig. S8
# +------------------------------------+--------------------+---------------------+
# | Model                              |  Scalar MAE (meV)  |  Force MAE (meV/Å)  |
# +====================================+====================+=====================+
# | 20% finetuned with pretraining     |       149.12       |        29.05        |
# | 40% finetuned with pretraining     |       121.24       |        25.00        |
# | 60% finetuned with pretraining     |       110.08       |        22.88        |
# | 80% finetuned with pretraining     |       103.63       |        21.68        |
# | 100% finetuned with pretraining    |       94.53        |        20.71        |
# | 100% finetuned without pretraining |       145.38       |        25.91        |
# +------------------------------------+--------------------+---------------------+
#
# NCI Atlas interaction energies in Extended Data Table 4
# +----------------+------------------+-------------------+
# | Subset         |  MAE (kcal/mol)  |  RMSE (kcal/mol)  |
# +================+==================+===================+
# | D1200          |       1.78       |       4.28        |
# | D442x10        |       1.89       |       4.96        |
# | HB300SPXx10    |       1.79       |       3.04        |
# | HB375x10       |       0.28       |       0.45        |
# | IHB100x10      |       4.87       |       8.26        |
# | R739x5         |       0.96       |       1.82        |
# | SH250x10       |       6.73       |       18.37       |
# | weighted_total |       2.03       |       6.92        |
# +----------------+------------------+-------------------+

# %%
# %%bash
# exec > >(tee -a "${RESULTS_DIR}/output.log") 2>&1
# echo -e "\nRun 1000 steps with AI2BMD-PIAM\nRunning ViSNet-PIMA for simulation..."
# cd "${SCRIPT_DIR}/AI2BMD-PIMA_simulation"
# bash simulation.sh "$@"
# Out:
# Run 1000 steps with AI2BMD-PIAM
# Running ViSNet-PIMA for simulation...
# DeviceStrategy: setting strategy to [large-molecule / combined]
# DeviceStrategy: Warning: libgomp bug detected. Lowering torch thread count to 1!
# Preprocessing step already done, skip...
# run_preprocess takes 0.001977205276489258 seconds
# Loading models...
# Initializing tinker...
# Initializing tinker...
# Pre-equilibration step already done, skip...
# Start simulation for 1000 steps
# Step 0:  Epot = -200359.406eV  Ekin = 787.152eV (T = 294K)  Etot = -199572.254eV
# Step 100:  Epot = -200354.109eV  Ekin = 781.670eV (T = 292K)  Etot = -199572.439eV
# Step 200:  Epot = -200351.672eV  Ekin = 777.829eV (T = 290K)  Etot = -199573.843eV
# Step 300:  Epot = -200350.234eV  Ekin = 779.290eV (T = 291K)  Etot = -199570.944eV
# Step 400:  Epot = -200349.859eV  Ekin = 780.832eV (T = 291K)  Etot = -199569.028eV
# Step 500:  Epot = -200353.578eV  Ekin = 782.930eV (T = 292K)  Etot = -199570.648eV
# Step 600:  Epot = -200353.125eV  Ekin = 785.199eV (T = 293K)  Etot = -199567.926eV
# Step 700:  Epot = -200344.359eV  Ekin = 778.630eV (T = 290K)  Etot = -199565.729eV
# Step 800:  Epot = -200348.469eV  Ekin = 784.649eV (T = 293K)  Etot = -199563.820eV
# Step 900:  Epot = -200346.938eV  Ekin = 783.814eV (T = 292K)  Etot = -199563.124eV
# Step 1000:  Epot = -200346.234eV  Ekin = 786.014eV (T = 293K)  Etot = -199560.221eV
# Simulation finished!
# Building PDB trajectory from trajectory...
# Done building PDB trajectory.
# Successfully finished running the simulation.
