# %%
# Run this cell for complate reproduction
# !./code/run.sh
# Out:
# /bin/bash: /home/sunxin/anaconda3/envs/DrugPT/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# bash: /home/sunxin/anaconda3/envs/DrugPT/lib/libtinfo.so.6: no version information available (required by bash)
# + cd /home/sunxin/GITHUB_MAINTAIN/ViSNet-PIMA/code/ViSNet-PIMA-final
# + bash inference_Chig.sh
# bash: /home/sunxin/anaconda3/envs/DrugPT/lib/libtinfo.so.6: no version information available (required by bash)
# Thu Sep 10 14:53:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.84                 Driver Version: 595.84         CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# ...
