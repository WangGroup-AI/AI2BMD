# %% [markdown]
# **Notebook Introduction**
#
# This notebook aims to reproduce the results of ViSNet-PIMA as presented in our research.

# %%
import os
import subprocess

# Setting CUDA_VISIBLE_DEVICES
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %% [markdown]
# *MD22-Ac_Ala3_NHMe*

# %%
# Run python scripts
command = "python train.py --conf examples_MD22_AIMD-Chig/ViSNet-MD22-Ac_Ala3_NHMe.yml --load-model \"../../data/checkpoint/Ac-Ala3-NHMe.ckpt\" --task inference --log-dir ../../results/log_md22_all"
subprocess.run(command, shell=True)
# Out:
# Seed set to 1
# computing mean and std:   0%|          | 0/1425 [00:00<?, ?it/s]
# train 5700, val 300, test 79109
# computing mean and std: 100%|██████████| 1425/1425 [00:09<00:00, 149.48it/s]
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'NeighborEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'EdgeEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'ViS_MP.jittable' is deprecated and a no-op. Please remove its usage.
# ...

# %% [markdown]
# *AT-AT-CG-CG*

# %%
# Run python scripts
command = "python train.py --conf examples_MD22_AIMD-Chig/ViSNet-MD22-AT_AT_CG_CG.yml --load-model \"../../data/checkpoint/AT-AT-CG-CG.ckpt\" --task inference --log-dir ../../results/log_md22_all"
subprocess.run(command, shell=True)
# Out:
# Seed set to 1
# computing mean and std:   0%|          | 0/475 [00:00<?, ?it/s]
# train 1900, val 100, test 8153
# computing mean and std: 100%|██████████| 475/475 [00:03<00:00, 126.98it/s]
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'NeighborEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'EdgeEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'ViS_MP.jittable' is deprecated and a no-op. Please remove its usage.
# ...

# %% [markdown]
# *Double-walled nanotube*

# %%
# Run python scripts
command = "python train.py --conf examples_MD22_AIMD-Chig/ViSNet-MD22-double_walled_nanotube.yml --load-model \"../../data/checkpoint/double-walled-nanotube.ckpt\" --task inference --log-dir ../../results/log_md22_all"
subprocess.run(command, shell=True)
# Out:
# Seed set to 1
# computing mean and std:   0%|          | 0/1900 [00:00<?, ?it/s]
# train 1900, val 100, test 3032
# computing mean and std: 100%|██████████| 1900/1900 [00:12<00:00, 150.05it/s]
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'NeighborEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'EdgeEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'ViS_MP.jittable' is deprecated and a no-op. Please remove its usage.
# ...

# %% [markdown]
# *AT-AT*

# %%
# Run python scripts
command = "python train.py --conf examples_MD22_AIMD-Chig/ViSNet-MD22-AT_AT.yml --load-model \"../../data/checkpoint/AT-AT.ckpt\" --task inference --log-dir ../../results/log_md22_all"
subprocess.run(command, shell=True)
# Out:
# Seed set to 1
# computing mean and std:   0%|          | 0/1188 [00:00<?, ?it/s]
# train 9500, val 500, test 10001
# computing mean and std: 100%|██████████| 1188/1188 [00:08<00:00, 143.56it/s]
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'NeighborEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'EdgeEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'ViS_MP.jittable' is deprecated and a no-op. Please remove its usage.
# ...

# %% [markdown]
# *Stachyose*

# %%
# Run python scripts
command = "python train.py --conf examples_MD22_AIMD-Chig/ViSNet-MD22-stachyose.yml --load-model \"../../data/checkpoint/stachyose.ckpt\" --task inference --log-dir ../../results/log_md22_all"
subprocess.run(command, shell=True)
# Out:
# Seed set to 1
# computing mean and std:   0%|          | 0/1900 [00:00<?, ?it/s]
# train 7600, val 400, test 19272
# computing mean and std: 100%|██████████| 1900/1900 [00:12<00:00, 147.45it/s]
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'NeighborEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'EdgeEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'ViS_MP.jittable' is deprecated and a no-op. Please remove its usage.
# ...

# %% [markdown]
# *DHA*

# %%
# Run python scripts
command = "python train.py --conf examples_MD22_AIMD-Chig/ViSNet-MD22-DHA.yml --load-model \"../../data/checkpoint/DHA.ckpt\" --task inference --log-dir ../../results/log_md22_all"
subprocess.run(command, shell=True)
# Out:
# Seed set to 1
# computing mean and std:   0%|          | 0/950 [00:00<?, ?it/s]
# train 7600, val 400, test 61753
# computing mean and std: 100%|██████████| 950/950 [00:06<00:00, 137.64it/s]
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'NeighborEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'EdgeEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'ViS_MP.jittable' is deprecated and a no-op. Please remove its usage.
# ...

# %% [markdown]
# *AIMD-Chignolin*

# %%
# Run python scripts 
command = "python train.py --conf examples_MD22_AIMD-Chig/ViSNet-Chignolin.yml --load-model \"../../data/checkpoint/Chignolin.ckpt\" --task inference --log-dir ../../results/log_md22_all"
subprocess.run(command, shell=True)
# Out:
# Seed set to 1
# train 79632, val 9954, test 9954
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'NeighborEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'EdgeEmbedding.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# /home/watong/mambaforge/envs/visnet_new2/lib/python3.9/site-packages/torch_geometric/nn/conv/message_passing.py:1032: UserWarning: 'ViS_MP.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# ...
